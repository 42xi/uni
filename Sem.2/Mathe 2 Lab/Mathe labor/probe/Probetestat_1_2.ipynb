# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import IFrame

# %%
x_min, x_max, y_min, y_max = -4, 4, -5, 7


x_ticks= np.arange(x_min, x_max+1, 1)
ax.set_xticks(x_ticks)

y_ticks= np.arange(y_min, y_max+1, 1)
ax.set_yticks(y_ticks)

ax.set_xticks(np.arange(x_min,x_max+1, 0.5),minor=True) 
ax.set_yticks(np.arange(y_min,y_max+1, 0.5),minor=True)
ax.grid(which='minor', alpha=0.1)
ax.grid(which='major', alpha=0.5)

x_werte = np.array([-3, 0,3,0,-2,2])
y_werte = np.array([-3,6,-3,6,0,0])

ax.plot(x_werte, y_werte, 'k')

alpha = np.radians(20)  # 20 Grad

R = np.array([[np.cos(alpha), -np.sin(alpha)], [np.sin(alpha), np.cos(alpha)]]) 

XY = np.array(x_werte), np.array(y_werte)

RXY = R@XY 

roted_x = RXY[0,:] 
roted_y = RXY[1,:]

ax.plot(roted_x,roted_y, 'r') 
display(fig)
